# %%
from ultralytics import YOLO
model = YOLO("yolov8n.pt")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from ultralytics import YOLO
#       2 model = YOLO("yolov8n.pt")
#
# File p:\Torchwork\lib\site-packages\ultralytics\__init__.py:10
#       7 # Set ENV Variables (place before imports)
#       8 os.environ["OMP_NUM_THREADS"] = "1"  # reduce CPU utilization during training
# ---> 10 from ultralytics.data.explorer.explorer import Explorer
#      11 from ultralytics.models import NAS, RTDETR, SAM, YOLO, FastSAM, YOLOWorld
#      12 from ultralytics.utils import ASSETS, SETTINGS
#
# File p:\Torchwork\lib\site-packages\ultralytics\data\__init__.py:3
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
# ----> 3 from .base import BaseDataset
#       4 from .build import build_dataloader, build_grounding, build_yolo_dataset, load_inference_source
#       5 from .dataset import (
# ...

# %%
# !pip install -U ultralytics
# Out:
# ...
#   Using cached torch-2.4.1-cp310-cp310-win_amd64.whl.metadata (27 kB)
# ...
# Using cached torch-2.4.1-cp310-cp310-win_amd64.whl (199.4 MB)
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 2.4.0
#     Uninstalling torch-2.4.0:
#       Successfully uninstalled torch-2.4.0
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.4.0+cu118 requires torch==2.4.0+cu118, but you have torch 2.4.1 which is incompatible.

# %%
results = model.train(
    data='data.yaml',  # Path to the data YAML file
    epochs=50,         # Number of training epochs
    batch=16,          # Batch size
    imgsz=640,         # Image size (can be adjusted based on your dataset)
    device=0           # GPU device (0 for the first GPU, 'cpu' for CPU)
)
# Out:
# Ultralytics YOLOv8.2.90  Python-3.10.14 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6140MiB)
# ...

# %%
import torch

if torch.cuda.is_available():
    print("GPU is available.")
    print("Device name:", torch.cuda.get_device_name(0))
else:
    print("GPU is not available.")
# Out:
# GPU is not available.

# %%
import torch
print(torch.cuda.is_available())  # Should return True if GPU is available
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import torch
#       2 print(torch.cuda.is_available())  # Should return True if GPU is available
#
# File p:\Torchwork\lib\site-packages\torch\__init__.py:137
#     135     err = ctypes.WinError(last_error)
#     136     err.strerror += f' Error loading "{dll}" or one of its dependencies.'
# --> 137     raise err
#     138 elif res is not None:
#     139     is_loaded = True
#
# OSError: [WinError 127] The specified procedure could not be found. Error loading "p:\Torchwork\lib\site-packages\torch\lib\c10_cuda.dll" or one of its dependencies.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from ultralytics import YOLO

# Load the YOLO model
model = YOLO(r'P:\dataset\ram\runs\detect\train\weights\best.pt')  # Replace 'best.pt' with your trained model

# Class names (replace with the actual class names used during training)
class_names= ['Cool', 'Hello', 'IloveYou', 'Namaste', 'ThankYou', 'fail', 'perfect']

# Load the image using OpenCV
cap = cv2.VideoCapture(0)

# Check if the webcam is opened correctly
if not cap.isOpened():
    print("Error: Could not open video stream.")
    exit()

# Set the resolution for faster processing
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)

while True:
    # Capture frame-by-frame from the webcam
    ret, frame = cap.read()
    
    if not ret:
        print("Failed to grab frame")
        break

    # Convert the frame to RGB for YOLO model (OpenCV uses BGR by default)
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    
    # Perform inference on the current frame (with a lower confidence threshold)
    results = model.predict(source=frame_rgb, save=False, conf=0.25)  # Adjust the threshold as needed
    
    # Draw the bounding boxes and class labels on the frame (specific to hand detections)
    for result in results:
        for box in result.boxes:
            # Extract the class id
            cls_id = int(box.cls[0])  # Get the class ID

            # If the detected class is related to hands or gestures
            if class_names[cls_id] in class_names:  # Replace with gesture classes
                # Extract the original bounding box coordinates
                x1, y1, x2, y2 = map(int, box.xyxy[0])

                # Adjust the height of the bounding box to focus more on hands
                box_height = y2 - y1
                box_width = x2 - x1
                
                # Shrink the bounding box height by focusing on a region around the center
                y_center = y1 + box_height // 2
                new_box_height = int(box_height * 0.5)  # 50% of the original height
                new_box_width = int(box_width * 0.8)    # 80% of the original width
                
                # Adjust the new coordinates to focus on the hand region
                new_y1 = max(y_center - new_box_height // 2, 0)
                new_y2 = min(y_center + new_box_height // 2, frame.shape[0])
                
                # Adjust x1 and x2 by the same proportion
                x_center = x1 + box_width // 2
                new_x1 = max(x_center - new_box_width // 2, 0)
                new_x2 = min(x_center + new_box_width // 2, frame.shape[1])

                # Draw the resized bounding box on the frame
                cv2.rectangle(frame, (new_x1, new_y1), (new_x2, new_y2), (0, 255, 0), 2)

                # Extract the confidence score
                conf = box.conf[0]

                # Get the class name
                class_name = class_names[cls_id]

                # Add the class name and confidence score
                label = f"{class_name}: {conf:.2f}"
                cv2.putText(frame, label, (new_x1, new_y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 0, 0), 2)

    # Display the frame with bounding boxes
    cv2.imshow('Sign Language Hand Detection', frame)

    # Break the loop if the 'q' key is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the webcam and close all OpenCV windows
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 (no detections), 82.8ms
# Speed: 8.7ms preprocess, 82.8ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.5ms
# Speed: 2.0ms preprocess, 57.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 48.9ms
# Speed: 1.0ms preprocess, 48.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 50.7ms
# Speed: 1.0ms preprocess, 50.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 51.0ms
# Speed: 1.0ms preprocess, 51.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 47.0ms
# Speed: 2.0ms preprocess, 47.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 49.6ms
# Speed: 2.0ms preprocess, 49.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# ...
